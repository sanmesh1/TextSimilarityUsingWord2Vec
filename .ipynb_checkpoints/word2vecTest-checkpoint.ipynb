# %%
#partial code borrowed from https://github.com/v1shwa/document-similarity

#need to download google word2vec pretrained model from https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit
#need to figure out how to do this. maybe something like wget

#packages to install
#numpy
#gensim
#fasttext

# %%
modelChosen = 'fasttext'

if modelChosen == 'word2vec':
    #load the pretrained word2Vec model
    from gensim.models.keyedvectors import KeyedVectors
    model_path = './data/GoogleNews-vectors-negative300.bin'
    w2v_model = KeyedVectors.load_word2vec_format(model_path, binary=True)
elif modelChosen == 'fasttext':
    #load the pretrained fastText model
    model_path = "data/wiki.en/wiki.en.bin"
#     import fasttext    
#     w2v_model = fasttext.load_model(model_path)    
    from gensim.models.wrappers import FastText
    model = FastText.load_fasttext_format(model_path)

# %%
#import the model into the document
from DocSim import DocSim
ds = DocSim(w2v_model)

# %%
#Create pandas dataframe on dataset
import pandas as pd
#https://data.world/crowdflower/ecommerce-search-relevance
df = pd.read_csv('https://query.data.world/s/iccclhgzbyedtv54p5lresglnun3qz', encoding = "ISO-8859-1")

# %%
#create source document and target document we will be comparing scores for
numDataPoints = 6000

sourceTitle = df['product_title'][2537]
source_doc = df['product_description'][2537]

targetTitles = df['product_title'][:numDataPoints].tolist()
target_docs = df['product_description'][:numDataPoints].tolist()

# %%
#debugging prints

#print(sourceTitle)
#print(source_doc)
#print(targetTitles[:2])
#print(target_docs[:2])
#print(type(source_doc))
#print(type(target_docs))
#print(type(['delete a invoice', 'how do i remove an invoice', 'purge an invoice']))

# %%
# Showing scores for all poducts above a certain threshold
threshold = 0.8
mod_target = target_docs
# Initialise data to lists.  
#data = [{'Title': 'Score', 'For': 'using', 'geeks': 'list'}, 
#        {'Geeks':10, 'For': 20, 'geeks': 30}]  
## Creates DataFrame.  
#df = pd.DataFrame(data) 

finalListOfDicts = []




print("Title of source product = ", sourceTitle)
print("")
print("Description of source product = ", source_doc)
print("")
print("Items with similarity threshold =  ", threshold, " are below:")
for i in range(len(mod_target)):
    if mod_target[i] == mod_target[i]:
        #print(i)
        sim_scores = ds.calculate_similarity(source_doc, mod_target[i])
        if sim_scores != [] and sim_scores[0]['score'] > threshold:
            #print(targetTitles[i])
            #print(sim_scores[0]['score'])
            finalListOfDicts.append({'Title': targetTitles[i], 'score': sim_scores[0]['score']})
            
        
dfFinal = pd.DataFrame(finalListOfDicts)
#dfFinal.sort_values(by=['score'], axis = 1, ascending=False)
dfNew = dfFinal.sort_values(by=['score'], ascending = False)
pd.set_option('display.max_colwidth', -1)
dfNew
#print(sim_scores)
# Out:
# Title of source product =  Levi's Women's Black Ink 'Perfect Waist' Straight Leg Jeans
#
# Description of source product =  The Perfect Waist 525 jeans by Levi's feature a no-gap waistband and a tummy-slimming waistband that flexes to fit your waist comfortably. Straight legs highlight this classic pair, designed with a five-pocket construction and tone-on-tone logo stitching on the flap pockets in back.
#
# Color options: Black ink
# Pockets: Two (2) front pockets, one (1) coin pocket, two (2) back flap button pockets
# Waist details: Natural
# Type of fly: Zipper with one (1) button
#
# The approximate inseam is 30 inches. The measurement was taken from a size 2M.
#
# Measurement Guide
# Click here to view our women's sizing guide
#
# Materials: 78-percent cotton/ 24-percent polyester/ 1-percent elastane
# Machine washable
# Model: 15564-0036
#
# Items with similarity threshold =   0.8  are below:
# /Users/sudhayakumar/opt/anaconda3/envs/fastTextEmbedding/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/sudhayakumar/opt/anaconda3/envs/fastTextEmbedding/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/sudhayakumar/opt/anaconda3/envs/fastTextEmbedding/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#                                                               Title     score
# 15   Levi's Women's Black Ink 'Perfect Waist' Straight Leg Jeans     1.000000
# 11   Levi's Women's 525 Denim Blue Perfect Waist Straight Jeans      0.920389
# 21   Levi's 512 Petite Skinny Boot Cut Black Denim Jeans             0.910948
# 12   Levi's Women's Petite Deep Night Leggings                       0.879143
# 18   Levi's 29 Curvy Jean Boot Cut Right On Blue                     0.877953
# ..                                           ...                          ...
# 94   Rashbi Men's Brown Dress Shirt                                  0.802291
# 115  Metal and Wood Standing Coat Rack                               0.802264
# 9    White Mark Women's Fit-and-Flare Floral Skater Dress            0.801261
# 78   Bogosse Men's Stripe and Printed Long Sleeve Button Down Shirt  0.801206
# 10   Max Lauren Men's Yellow Dress Shirt                             0.800125
#
# [128 rows x 2 columns]
